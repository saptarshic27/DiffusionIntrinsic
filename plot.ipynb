# %%
import torch
import numpy
import numpy as np

# %%
test_errors_10 = torch.load('goldfish_10.pt')
test_errors_100 = torch.load('goldfish_100.pt')
test_errors_10 = test_errors_10.cpu().numpy()
test_errors_100 = test_errors_100.cpu().numpy()


import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.size'] = 15
plt.figure(figsize=(5, 4.5))

x = [1000,2000,3000,4000,5000,6000,7000,8000,9000,10000]

# --- d_int = 10 ---
y = np.mean(test_errors_10, axis=1)
y_error = np.std(test_errors_10, axis=1)
plt.errorbar(
    x, y, yerr=y_error, marker='o', linestyle='-', 
    label='d = 10', capsize=3 , color='tab:green'
)

# --- d_int = 100 ---
y = np.mean(test_errors_100, axis=1)
y_error = np.std(test_errors_16, axis=1)
plt.errorbar(
    x, y, yerr=y_error, marker='o', linestyle='-',
    label='d = 100', capsize=3 , color='tab:orange'
)

plt.xlabel("Number of training samples")
plt.ylabel("FID Score")

plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.20), ncol=2)
plt.tight_layout()
plt.savefig("diff_100_10_goldfish.pdf", bbox_inches="tight")
#plt.savefig("GAN_gen.pdf", bbox_inches="tight")
plt.show()
